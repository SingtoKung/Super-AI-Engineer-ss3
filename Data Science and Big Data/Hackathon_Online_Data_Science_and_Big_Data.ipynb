# %% [markdown]
# # Setting and Install

# %%
# install kaggle cli
# !pip install kaggle -qq
# !pip install autoviz -Uq
# !pip install matplotlib
# !pip install pycaret
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Prepare dataset

# %%
# !kaggle competitions download -c hackathon-online-data-science-and-big-data

# %%
# !unzip -o /content/hackathon-online-data-science-and-big-data.zip

# %%
occupation = pd.read_csv("/content/occupation.csv")
occupation

# %%
dict_occ = occupation['id'].to_dict()
dict_occ

# %%
main_occ = pd.DataFrame(occupation['main'].unique(), columns = ['main'])
dict_main = main_occ['main'].to_dict()
dict_main

# %%
rev_occ = dict(map(reversed, dict_occ.items()))
rev_occ

# %%
rev_main = dict(map(reversed, dict_main.items()))
rev_main

# %%
rev_main2 = {'A ': 0,
 'B ': 1,
 'C ': 2,
 'D ': 3,
 'E ': 4,
 'F ': 5,
 'G ': 6,
 'H ': 7,
 'I ': 8,
 'J ': 9,
 'K ': 10,
 'L ': 11,
 'M ': 12,
 'N ': 13,
 'O ': 14,
 'P ': 15,
 'Q ': 16}

# %%
types = pd.read_csv("/content/type.csv")
types
# Out:
#       id                                               type
# 0    BD1                                     ผลิตภัณฑ์อาหาร
# 1    BD2                                        เครื่องดื่ม
# 2    BD3                                     ผลิตภัณฑ์ยาสูบ
# 3    BD4                                             สิ่งทอ
# 4    BD5              เสื้อผ้าเครื่องแต่งกาย รองเท้า แว่นตา
# 5    BD6               เครื่องหนังและผลิตภัณฑ์ที่เกี่ยวข้อง
# 6    BD7  ไม้และผลิตภัณฑ์จากไม้และไม้ก๊อก (ยกเว้นเฟอร์นิ...
# 7    BD8                           กระดาษและผลิตภัณฑ์กระดาษ
# 8    BD9                     การพิมพ์และซ้ำสื่อบันทึกข้อมูล
# 9   BD10    ถ่านโค้กและผลิตภัณฑ์ที่ได้จากการกลั่นปิโตรเลียม
# 10  BD11                          เคมีภัณฑ์และผลิตภัณฑ์เคมี
# 11  BD12  เภสัชภัณฑ์ เคมีภัณฑ์ที่ใช้รักษาโรค และผลิตภัณฑ...
# 12  BD13                             ผลิตภัณฑ์ยางและพลาสติก
# 13  BD14  แก้ว เซรามิก คอนกรีต ปูนซีเมนต์ ขึ้นรูปหิน กระ...
# 14  BD15                                        โลหะ เหล็ก
# ...

# %%
dict_types = types['id'].to_dict()
dict_types
# Out:
# {0: 'BD1',
#  1: 'BD2',
#  2: 'BD3',
#  3: 'BD4',
#  4: 'BD5',
#  5: 'BD6',
#  6: 'BD7',
#  7: 'BD8',
#  8: 'BD9',
#  9: 'BD10',
#  10: 'BD11',
#  11: 'BD12',
#  12: 'BD13',
#  13: 'BD14',
#  14: 'BD15',
#  15: 'BD16',
#  16: 'BD17',
#  17: 'BD18',
#  18: 'BD19',
#  19: 'BD20',
#  20: 'BD21',
#  21: 'BD22',
#  22: 'BD23',
#  23: 'BD24',
#  24: 'BD25',
#  25: 'BD26',
#  26: 'BD27',
#  27: 'BD28',
#  28: 'BD29',
#  29: 'BD30'}

# %%
rev_types = dict(map(reversed, dict_types.items()))
rev_types
# Out:
# {'BD1': 0,
#  'BD2': 1,
#  'BD3': 2,
#  'BD4': 3,
#  'BD5': 4,
#  'BD6': 5,
#  'BD7': 6,
#  'BD8': 7,
#  'BD9': 8,
#  'BD10': 9,
#  'BD11': 10,
#  'BD12': 11,
#  'BD13': 12,
#  'BD14': 13,
#  'BD15': 14,
#  'BD16': 15,
#  'BD17': 16,
#  'BD18': 17,
#  'BD19': 18,
#  'BD20': 19,
#  'BD21': 20,
#  'BD22': 21,
#  'BD23': 22,
#  'BD24': 23,
#  'BD25': 24,
#  'BD26': 25,
#  'BD27': 26,
#  'BD28': 27,
#  'BD29': 28,
#  'BD30': 29}

# %%
train_data = pd.read_csv("/content/train_data.csv")
train_data.head(15)

# %%
train_target = pd.read_csv("/content/train_target.csv")
train_target.head(15)

# %%
datasets = train_data
datasets['labels'] = train_target['Car']
datasets.head(15)

# %%
datasets.isnull().sum().sum()
# Out:
# 0

# %%
datasets.isnull().any()

# %%
data_description = pd.read_csv("/content/data_description.csv")
data_description

# %%
train_data['Q1_OccStatus'].value_counts()

# %%
datasets['Q1_OccCode'].head(15)

# %%
#Select data for train model
train_data = datasets.iloc[:, 1:] #Select column 2nd to end
train_data

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20966 entries, 0 to 20965
# Columns: 144 entries, Area to labels
# dtypes: float64(5), int64(107), object(32)
# memory usage: 23.0+ MB

# %%
train_data.replace({'Q1_OccCode': rev_occ, 'Q1_OccInd': rev_main, 'Q1_IndBD_1': rev_types, 'Q1_IndBD_2': rev_types, 'Q1_IndBD_3': rev_types}, inplace=True)

# %%
train_data.replace({'Q2.1_OccCode': rev_occ, 'Q2.1_OccInd': rev_main}, inplace=True)

# %%
train_data.replace({'Q2.2_OccCode': rev_occ, 'Q2.2_OccInd': rev_main}, inplace=True)

# %%
fix01 = {'BD23': 888, 'BD5': 888, 'A1/A2': 888} #Fix question 2 (Q2)
fix02 = {4: 888, 6: 888} #Fix question 4 (Q4)
fix03 = {0: 888} #Fix question 10 (Q10)
fix04 = {'1': 888} #Fix LiveOther

# %%
#clean data
train_data.replace({'Q1_OccInd': rev_main2, 'Q2.1_OccInd': rev_main2}, inplace=True)
train_data.replace({'Q2.1_OccCode': fix01}, inplace=True)
train_data.replace({'Q4_4': fix02, 'Q4_6': fix02}, inplace=True)
train_data.replace({'Q10.4': fix03}, inplace=True)
train_data.replace({'LiveOther': fix04}, inplace=True)

# %%
train_data

# %%
train_data['Q1_OccCode'].unique()
# Out:
# array([ 84,  18,  11, 141, 147,  30,  24,  15,  25,  31,  33,  52, 153,
#        118,   1, 144, 159,   9,   0,  37,  40,  38,   7,  16, 113,  36,
#         17,  12,  22,  74,  19,  34,  61,  41,  85, 145, 156, 105, 137,
#         23, 139, 161, 119, 157,  90,  95,  87,  91,  93, 149,  92, 127,
#        146,   2,  58,  89, 111,  81,  10, 125,  47,   3, 103,  54,  50,
#         66,  28,  46,  51, 142,  86,  83,  42,  57, 150,  70,   4,  71,
#         35,  56,  20, 160,  96,  65,  49,  76,   8,  69,  32, 162, 106,
#         79, 158,  39, 155, 129,  68, 165, 122,  62, 140,  21, 135,   6,
#         27,  78,  26, 154,  14,  63, 100,  44,  94,  60, 130, 104, 148,
#        152,  99,  82, 164,  88,  53, 136, 151,  98, 128, 110,  13,  64,
#         67, 116])

# %%
train_data.iloc[:,132]
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 20961    1
# 20962    2
# 20963    1
# 20964    2
# 20965    1
# Name: Line, Length: 20966, dtype: int64

# %%
train_data.iloc[:,132].unique()
# Out:
# array([  2,   1, 999])

# %%
st = ['SubDistrict', 'District', 'Province', 'Q1_Occ', 'Q2.1_Occ', 'Q2.2_Occ', 'Q3.3Reason', 'Q4_7Other', 'Q5_9Other', 'Q9_9Other', 
      'Q10.1_1', 'Q10.1_2', 'Q10.1_3', 'Q10.1_4', 'Q10.1_5', 'Q10.2_1', 'Q10.2_2', 'Q10.2_3', 'Q10.2_4', 'Q10.2_5', 'AssetOther']

# %%
# Check unique value
def check_unique_value(data):
  count_un = []
  for i, columns in enumerate(data.columns):
    count_un.append(len(data.iloc[:,i].unique()))
  return count_un

# %% [markdown]
# # Change data to class by LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
my_data = train_data.iloc[:,:132]
my_data['labels'] = train_data['labels']
my_data
# Out:
#        Area          SubDistrict                  District         Province  \
# 0         1              หนองบอน                    ประเวศ         กรุงเทพฯ
# 1         2  เทศบาลตำบลนครชัยศรี                 นครชัยศรี           นครปฐม
# 2         1              บางซื่อ                   บางซื่อ         กรุงเทพฯ
# 3         2              หาดใหญ่          เทศบาลนครหาดใหญ่            สงขลา
# 4         2              ในเมือง        เทศบาลเมืองบ้านไผ่          ขอนแก่น
# ...     ...                  ...                       ...              ...
# 20961     2            หอรัตนไชย  เทศบาลนครพระนครศรีอยุธยา  พระนครศรีอยุธยา
# 20962     2              ในเมือง        เทศบาลเมืองหนองคาย          หนองคาย
# 20963     2             พนัสนิคม       เทศบาลเมืองพนัสนิคม           ชลบุรี
# 20964     2              ในเมือง    เทศบาลเมืองบุรีรัมย์_1        บุรีรัมย์
# 20965     2     เทศบาลตำบลไม้งาม                  เมืองตาก              ตาก
#
# ...

# %%
filter_data = my_data.drop(['SubDistrict', 'District', 'Province', 'Q1_Occ', 'Q2.1_Occ', 'Q2.2_Occ', 'Q3.3Reason', 'Q4_7Other', 'Q5_9Other', 'Q9_9Other', 
                            'Q10.1_1', 'Q10.1_2', 'Q10.1_3', 'Q10.1_4', 'Q10.1_5', 'Q10.2_1', 'Q10.2_2', 'Q10.2_3', 'Q10.2_4', 'Q10.2_5', 'AssetOther', 'LiveOther'], axis = 1)
filter_data
# Out:
#        Area  Region  Q1_OccStatus  Q1_OccCode  Q1_OccInd Q1_IndBD_1  \
# 0         1       1             3          84         11        888
# 1         2       2             1          18          3          0
# 2         1       1             3          18          3         25
# 3         2       5             3          11          2        888
# 4         2       4             3          84         11        888
# ...     ...     ...           ...         ...        ...        ...
# 20961     2       2             1          18          3          0
# 20962     2       4             1          18          3          0
# 20963     2       2             1          17          3          4
# 20964     2       4             1         146         15        888
# 20965     2       3             1          79         11        888
#
#       Q1_IndBD_2 Q1_IndBD_3  Q1_Occ_Year  Q1_OCC_A  ...  Age  Status  Child  \
# ...

# %%
filter_data[filter_data.eq("อยู่กับนายจ้าง").any(1)]
# Out:
#        Area  Region  Q1_OccStatus  Q1_OccCode  Q1_OccInd Q1_IndBD_1  \
# 1650      2       2             3          36          6        888
# 2312      2       2             3          11          2        888
# 3180      3       2             3          84         11        888
# 5533      1       1             3          18          3         26
# 9475      1       1             3          36          6        888
# 10057     2       3             3          15          3          4
# 10229     3       2             3          35          6        888
# 16113     2       2             3          18          3          0
# 18676     3       2             3          15          3         21
# 18696     2       2             3          15          3          3
# 20175     2       2             3          18          3          0
#
#       Q1_IndBD_2 Q1_IndBD_3  Q1_Occ_Year  Q1_OCC_A  ...  Status  Child  Edu  \
# ...

# %% [markdown]
# # Train model

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
X = filter_data.iloc[:,:-1]
y = filter_data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1)

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7715784453981879

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
filter_data.columns[:-1]
# Out:
# Index(['Area', 'Region', 'Q1_OccStatus', 'Q1_OccCode', 'Q1_OccInd',
#        'Q1_IndBD_1', 'Q1_IndBD_2', 'Q1_IndBD_3', 'Q1_Occ_Year', 'Q1_OCC_A',
#        ...
#        'Sex', 'Age', 'Status', 'Child', 'Edu', 'Salary', 'Live', 'Owner',
#        'Owner_loan', 'Owner_rent'],
#       dtype='object', length=110)

# %%
feature_imp = pd.Series(clf.feature_importances_,index=filter_data.columns[:-1]).sort_values(ascending=False)
feature_imp.head(40)
# Out:
# Q5_2B            0.060212
# Q5_TotalB        0.052270
# Age              0.050898
# Q5_2A            0.048894
# Q5_TotalA        0.047823
# Salary           0.043602
# Q8_2A            0.042719
# Q1_Occ_Year      0.037430
# Q8_2B            0.032817
# Edu              0.027494
# Region           0.019858
# Child            0.018718
# Q1_OccCode       0.018350
# Q4Most           0.017750
# Q10Num           0.017640
# Sex              0.016031
# Q1_OCC_B_Num     0.015744
# Q1_IndBD_1       0.015352
# Owner_rent       0.014878
# Q1_OccStatus     0.014228
# Owner_loan       0.013794
# Q5_2             0.012819
# Status           0.012445
# Q3.1Year         0.012163
# Q3.2Year         0.012019
# Q10.3_Percent    0.011927
# Q7_1Day          0.011676
# Area             0.011350
# Q8_3B            0.010709
# Live             0.010546
# Owner            0.009920
# Q8B              0.009295
# Q4_2             0.008951
# Q1_OCC_B         0.008654
# Q10.4            0.008458
# ...

# %%
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
X_new = filter_data[['Q5_2B', 'Q5_TotalB']]
y_new = filter_data.iloc[:,-1]

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X_new, y_new, test_size=0.2, random_state = 1)

# %%
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X2_train,y2_train)

y2_pred=clf.predict(X2_test)

# %%
print("Accuracy:",metrics.accuracy_score(y2_test, y2_pred))
# Out:
# Accuracy: 0.7114926084883166

# %% [markdown]
# # Save model

# %%
import joblib
# Fit the model on training set
model = RandomForestClassifier()
model.fit(X_train, y_train)
# save the model to disk
filename = 'finalized_model.sav'
joblib.dump(model, filename)
# Out:
# ['finalized_model.sav']

# %% [markdown]
# # Test data

# %%
lst = filter_data.columns[:-1].to_list()
lst
# Out:
# ['Area',
#  'Region',
#  'Q1_OccStatus',
#  'Q1_OccCode',
#  'Q1_OccInd',
#  'Q1_IndBD_1',
#  'Q1_IndBD_2',
#  'Q1_IndBD_3',
#  'Q1_Occ_Year',
#  'Q1_OCC_A',
#  'Q1_OCC_A_Month',
#  'Q1_OCC_B',
#  'Q1_OCC_B_Num',
#  'Q1_OCC_C',
#  'Q1_Occ_Have',
#  'Q2',
#  'Q2_OccNum',
#  'Q2.1_OccStatus',
#  'Q2.1_OccCode',
#  'Q2.1_OccInd',
#  'Q2.1A',
#  'Q2.2_OccStatus',
#  'Q2.2_OccCode',
#  'Q2.2_OccInd',
#  'Q2.2A',
#  'Q3Num',
#  'Q3No',
#  'Q3.1Year',
#  'Q3.1LessYear',
#  'Q3.1Month',
#  'Q3.2Year',
#  'Q3.2LessYear',
#  'Q3.2Month',
#  'Q4_1',
#  'Q4_2',
#  'Q4_3',
#  'Q4_4',
#  'Q4_5',
#  'Q4_6',
#  'Q4_7',
#  'Q4Most',
#  'Q5_1',
#  'Q5_1A',
#  'Q5_1B',
#  'Q5_2',
#  'Q5_2A',
#  'Q5_2B',
#  'Q5_3',
#  'Q5_3A',
#  'Q5_3B',
#  'Q5_4',
#  'Q5_4A',
#  'Q5_4B',
#  'Q5_5',
#  'Q5_5A',
#  'Q5_5B',
#  'Q5_6',
#  'Q5_6A',
#  'Q5_6B',
#  'Q5_7',
#  'Q5_7A',
#  'Q5_7B',
#  'Q5_8',
#  'Q5_8A',
#  'Q5_8B',
#  'Q5_9',
#  'Q5_9A',
#  'Q5_9B',
#  'Q5_TotalA',
#  'Q5_TotalB',
#  'Q7_1',
#  'Q7_1Day',
# ...

# %%
test_data = pd.read_csv('/content/test_data.csv')
pred_data = test_data[lst]
pred_data
# Out:
#       Area  Region  Q1_OccStatus Q1_OccCode Q1_OccInd Q1_IndBD_1 Q1_IndBD_2  \
# 0        2       4             3        P10         P        888        888
# 1        2       5             1         D1         D        BD1        999
# 2        3       5             1         D1         D        BD4        999
# 3        1       1             1         D4         D        BD1        999
# 4        2       2             3        O17         O        888        888
# ...    ...     ...           ...        ...       ...        ...        ...
# 5195     3       3             1         D4         D       BD27        999
# 5196     2       4             1         D4         D        BD1        999
# 5197     3       3             1         D4         D        BD1        999
# 5198     2       2             1         D4         D        BD1        999
# 5199     2       5             1         D4         D        BD6        999
#
# ...

# %%
pred_data.replace({'Q1_OccCode': rev_occ, 'Q1_OccInd': rev_main, 'Q1_IndBD_1': rev_types, 'Q1_IndBD_2': rev_types, 'Q1_IndBD_3': rev_types}, inplace=True)

# %%
pred_data.replace({'Q2.1_OccCode': rev_occ, 'Q2.1_OccInd': rev_main}, inplace=True)

# %%
pred_data.replace({'Q2.2_OccCode': rev_occ, 'Q2.2_OccInd': rev_main}, inplace=True)

# %%
#clean data
pred_data.replace({'Q1_OccInd': rev_main2, 'Q2.1_OccInd': rev_main2}, inplace=True)
pred_data.replace({'Q2.1_OccCode': fix01}, inplace=True)
pred_data.replace({'Q4_4': fix02, 'Q4_6': fix02}, inplace=True)
pred_data.replace({'Q10.4': fix03}, inplace=True)
pred_data.replace({'LiveOther': fix04}, inplace=True)

# %%
filter_test_data[filter_test_data.eq("App Grab").any(1)]
# Out:
#         Id  Area  Region  Q1_OccStatus  Q1_OccCode  Q1_OccInd Q1_IndBD_1  \
# 241    241     2       5             4          31          5        888
# 431    431     2       5             4          31          5        888
# 433    433     2       5             4          61         10        888
# 442    442     2       5             4          31          5        888
# 464    464     2       5             4          31          5        888
# 487    487     2       5             4          31          5        888
# 874    874     2       5             4          31          5        888
# 984    984     2       5             4          31          5        888
# 1009  1009     2       4             4          31          5        888
# 1141  1141     2       5             4          31          5        888
# 1419  1419     2       4             4          31          5        888
# 1443  1443     2       5             4          31          5        888
# ...

# %%
loaded_model = joblib.load(filename)
predicts = loaded_model.predict(pred_data)
predicts
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
ss = pd.read_csv('/content/sample_submission.csv')
ss
# Out:
#         Id  Predicted
# 0        0        0.0
# 1        1        1.0
# 2        2        1.0
# 3        3        NaN
# 4        4        NaN
# ...    ...        ...
# 5195  5195        NaN
# 5196  5196        NaN
# 5197  5197        NaN
# 5198  5198        NaN
# 5199  5199        NaN
#
# [5200 rows x 2 columns]

# %%
ss['Predicted'] = predicts

# %%
ss
# Out:
#         Id  Predicted
# 0        0          0
# 1        1          1
# 2        2          1
# 3        3          0
# 4        4          0
# ...    ...        ...
# 5195  5195          1
# 5196  5196          0
# 5197  5197          0
# 5198  5198          1
# 5199  5199          1
#
# [5200 rows x 2 columns]

# %%
ss.to_csv('submit_rev01.csv', index=False)
